# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df = pd.read_csv('C:/Users/user/Desktop/final/student_performance_new (1).csv')

# %%
df.isna().sum()
# Out:
# Sl.No.                0
# USN                   0
# STUDENT NAME          0
# Test I                0
# Test II               0
# Test III              0
# Test Total            0
# Test Result           0
# Quiz 1                0
# Quiz 2                0
# Compensatory          1
# Quiz                  0
# Quiz Result           0
# Test + Quiz           0
# Assignment            0
# Unnamed: 15           0
# Assignment Result     0
# Result                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 0 to 53
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sl.No.              53 non-null     int64
#  1   USN                 53 non-null     object
#  2   STUDENT NAME        53 non-null     object
#  3   Test I              53 non-null     int64
#  4   Test II             53 non-null     int64
#  5   Test III            53 non-null     int64
#  6   Test Total          53 non-null     float64
#  7   Test Result         53 non-null     int64
#  8   Quiz 1              53 non-null     float64
#  9   Quiz 2              53 non-null     float64
#  10  Compensatory        53 non-null     float64
#  11  Quiz                53 non-null     float64
#  12  Quiz Result         53 non-null     int64
#  13  Test + Quiz         53 non-null     float64
#  14  Assignment          53 non-null     int64
# ...

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Sl.No.                0
# USN                   0
# STUDENT NAME          0
# Test I                0
# Test II               0
# Test III              0
# Test Total            0
# Test Result           0
# Quiz 1                0
# Quiz 2                0
# Compensatory          0
# Quiz                  0
# Quiz Result           0
# Test + Quiz           0
# Assignment            0
# Unnamed: 15           0
# Assignment Result     0
# Result                0
# dtype: int64

# %%
x=df.drop(["STUDENT NAME", "USN", "Result"], axis=1)
y=df["Result"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 0 to 53
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sl.No.              53 non-null     int64
#  1   USN                 53 non-null     object
#  2   STUDENT NAME        53 non-null     object
#  3   Test I              53 non-null     int64
#  4   Test II             53 non-null     int64
#  5   Test III            53 non-null     int64
#  6   Test Total          53 non-null     float64
#  7   Test Result         53 non-null     int64
#  8   Quiz 1              53 non-null     float64
#  9   Quiz 2              53 non-null     float64
#  10  Compensatory        53 non-null     float64
#  11  Quiz                53 non-null     float64
#  12  Quiz Result         53 non-null     int64
#  13  Test + Quiz         53 non-null     float64
#  14  Assignment          53 non-null     int64
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20, random_state=42)

# %%
clf=DecisionTreeClassifier(random_state=42)

# %%
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred=clf.predict(x_test)
y
# Out:
# 0     1
# 1     1
# 3     1
# 4     1
# 5     0
# 6     0
# 7     1
# 8     1
# 9     1
# 10    1
# 11    0
# 12    0
# 13    1
# 14    0
# 15    0
# 16    1
# 17    0
# 18    0
# 19    1
# 20    0
# 21    0
# 22    1
# 23    1
# 24    0
# 25    0
# 26    0
# 27    0
# 28    0
# 29    1
# 30    0
# 31    1
# 32    1
# 33    1
# 34    0
# 35    1
# 36    1
# 37    1
# 38    0
# 39    1
# 40    1
# 41    0
# 42    1
# 43    0
# 44    0
# 45    1
# 46    0
# 47    0
# 48    0
# 49    1
# 50    0
# 51    0
# 52    0
# 53    1
# Name: Result, dtype: int64

# %%
plt = plot_tree(clf, class_names=["Pass", "Fail"], filled=True)

# %%
a = accuracy_score(y_test, y_pred)
a
# Out:
# 0.8181818181818182

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86         7
#            1       0.75      0.75      0.75         4
#
#     accuracy                           0.82        11
#    macro avg       0.80      0.80      0.80        11
# weighted avg       0.82      0.82      0.82        11

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[6, 1],
#        [1, 3]], dtype=int64)

# %%
sns.heatmap(cm, annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
x_train
# Out:
#     Sl.No.  Test I   Test II   Test III  Test Total   Test Result   Quiz 1  \
# 9       10       22        30        18    23.333333             0     3.5
# 27      28       28        30         5    21.000000             0     3.0
# 7        8       12        22        17    17.000000             0     6.0
# 35      37       25        32        18    25.000000             1     5.0
# 5        6       27        33        22    27.333333             1     6.5
# 38      40       14        16        19    16.333333             0     5.0
# 25      26       17        29        18    21.333333             0     4.0
# 45      47       25        33        20    26.000000             1     5.0
# 34      36       15        28        16    19.666667             0     5.0
# 50      52       25        29        13    22.333333             0     6.0
# 16      17       25        36        27    29.333333             1     7.0
# ...

# %%
resu = clf.predict([[41,29,29,18,25.333333,1,5.0,6.0,10.0,16.0,1,41.333333,14,14,1]])
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
if resu[0] == 1:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
resu = clf.predict([[16,14,20,8,14.000000,0,4.5,6.0,7.0,13.0,1,27.000000,14,14,1]])
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
if resu[0] == 1:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %%
resu = clf.predict([[16,34,17,22,27.333333,1,5.0,6.0,10.0,16.0,1,43.333333,15,15,1]])
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
if resu[0] == 1:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
resu = clf.predict([[30,34,43,26,34.333333,1,6.5,6.0,9.0,15.5,1,49.833333,15,15,1]])
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
if resu[0] == 1:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
val = [[30,34,43,26,34.333333,1,6.5,6.0,9.0,15.5,1,49.833333,15,15,1],
      [16,34,17,22,27.333333,1,5.0,6.0,10.0,16.0,1,43.333333,15,15,1],
      [41,29,29,18,25.333333,1,5.0,6.0,10.0,16.0,1,41.333333,14,14,1]]
for x in val:
    print(resu)
# Out:
# [1]
# [1]
# [1]
